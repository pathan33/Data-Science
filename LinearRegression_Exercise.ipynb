# %% [markdown]
# <a href="https://colab.research.google.com/github/pathan33/Data-Science/blob/master/LinearRegression_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Machine Learning With Python: Linear Regression With One Variable

# %%
## Creating a Pandas DataFrame
import pandas as pd

# Define the data
data = {
    "year": [
        1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979,
        1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989,
        1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999,
        2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009,
        2010, 2011, 2012, 2013, 2014, 2015, 2016
    ],
    "per capita income (US$)": [
        3399.299037, 3768.297935, 4251.175484, 4804.463248, 5576.514583,
        5998.144346, 7062.131392, 7100.12617, 7247.967035, 7602.912681,
        8355.96812, 9434.390652, 9619.438377, 10416.53659, 10790.32872,
        11018.95585, 11482.89153, 12974.80662, 15080.28345, 16426.72548,
        16838.6732, 17266.09769, 16412.08309, 15875.58673, 15755.82027,
        16369.31725, 16699.82668, 17310.75775, 16622.67187, 17581.02414,
        18987.38241, 18601.39724, 19232.17556, 22739.42628, 25719.14715,
        29198.05569, 32738.2629, 36144.48122, 37446.48609, 32755.17682,
        38420.52289, 42334.71121, 42665.25597, 42676.46837, 41039.8936,
        35175.18898, 34229.19363
    ]
}

# Create the DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
print(df)
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import linear_model

# %%
plt.scatter(df['year'], df['per capita income (US$)'], color='red', marker="+")
plt.xlabel("Year")
plt.ylabel("Per Capita Income (US$)")
# Out:
# Text(0, 0.5, 'Per Capita Income (US$)')

# %%
## Create the X and Y Variables data
new_df = df.drop('per capita income (US$)', axis='columns')
new_df.head()

#X = df[['year']]
#y = df['per capita income (US$)']
# Out:
#    year
# 0  1970
# 1  1971
# 2  1972
# 3  1973
# 4  1974

# %%
per_captia_income = df['per capita income (US$)']
per_captia_income.head()
# Out:
# 0    3399.299037
# 1    3768.297935
# 2    4251.175484
# 3    4804.463248
# 4    5576.514583
# Name: per capita income (US$), dtype: float64

# %%
# Create linear regression object
reg = linear_model.LinearRegression()
reg.fit(new_df, per_captia_income)
# Out:
# LinearRegression()

# %% [markdown]
# (1) Predict the per capita income fo canadian citizens in year 2020

# %%
reg.predict([[2020]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
reg.predict([[2020],[2021]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442, 42117.15916964])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
reg.coef_
# Out:
# array([828.46507522])

# %%
reg.intercept_
# Out:
# np.float64(-1632210.7578554575)

# %%
828.46507522 * 2020 + -1632210.7578554575
# Out:
# 41288.694088942604

# %% [markdown]
# ## **Reshaping of the inputs for the Prediction**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
years = [2020, 2021, 2022]
import numpy as np
reg.predict(np.array(years).reshape(-1, 1))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442, 42117.15916964, 42945.62424486])

# %%
np.array(years)
# Out:
# array([2020, 2021, 2022])

# %%
np.array(years).shape
# Out:
# (3,)

# %%
np.array(years).reshape(-1,1)
# Out:
# array([[2020],
#        [2021],
#        [2022]])

# %%
np.array(years).reshape(-1,1).shape
# Out:
# (3, 1)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)
